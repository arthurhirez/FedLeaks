# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from utils.Toolbox_detection import combined_value_counts, plot_sankley

df_detect = pd.read_csv(f'results/income_base/traceback/INCOMESIMPLE/compiled_detection.csv')
# df_similarity = pd.read_csv(f'results/density_base/traceback/NEW_WINDOW/compiled_similarity.csv')

# %%
df_detect['state_map'].unique()
# Out:
# array(['LL_HL__HL_LL_LL_LL_ML', 'LL_HL__HL_LL_LL_ML_LL',
#        'LL_HL__HL_LL_ML_LL_LL', 'LL_HL__HL_ML_LL_LL_LL',
#        'LL_HL__LL_HL_LL_LL_ML', 'LL_HL__LL_HL_LL_ML_LL',
#        'LL_HL__LL_HL_ML_LL_LL', 'LL_HL__LL_LL_HL_LL_ML',
#        'LL_HL__LL_LL_HL_ML_LL', 'LL_HL__LL_LL_LL_HL_ML',
#        'LL_HL__LL_LL_LL_ML_HL', 'LL_HL__LL_LL_ML_HL_LL',
#        'LL_HL__LL_LL_ML_LL_HL', 'LL_HL__LL_ML_HL_LL_LL',
#        'LL_HL__LL_ML_LL_HL_LL', 'LL_HL__ML_HL_LL_LL_LL',
#        'LL_HL__ML_LL_HL_LL_LL', 'LL_ML__HL_LL_LL_LL_ML',
#        'LL_ML__HL_LL_LL_ML_LL', 'LL_ML__HL_LL_ML_LL_LL',
#        'LL_ML__HL_ML_LL_LL_LL', 'LL_ML__LL_HL_LL_LL_ML',
#        'LL_ML__LL_HL_LL_ML_LL', 'LL_ML__LL_HL_ML_LL_LL',
#        'LL_ML__LL_LL_HL_LL_ML', 'LL_ML__LL_LL_HL_ML_LL',
#        'LL_ML__LL_LL_LL_HL_ML', 'LL_ML__LL_LL_LL_ML_HL',
#        'LL_ML__LL_LL_ML_HL_LL', 'LL_ML__LL_LL_ML_LL_HL',
#        'LL_ML__LL_ML_HL_LL_LL', 'LL_ML__LL_ML_LL_HL_LL',
#        'LL_ML__ML_HL_LL_LL_LL', 'LL_ML__ML_LL_HL_LL_LL'], dtype=object)

# %%
window [12, 48, 84]
step_size [2]
interval [4]
lstm [40, 10, 30, 60]
info [0.4, 0.2, 0.05, 0.1]
ground_truth ['B', 'C', 'D', 'E', 'A']
final_state ['HL', 'ML']
similar_districts ['A', 'B', 'C', 'D', 'E']
com_epoch [10, 5]

# %%
processed_detect = df_detect.copy()
processed_detect[['window', 'step_size', 'interval']] = processed_detect['setup'].str.split('_', expand = True).astype(int)

processed_detect['interval'] = (processed_detect['interval'] / 3600).astype(int)
processed_detect['step_ratio'] = round(processed_detect['step_size']  / processed_detect['window'], 3)


processed_detect['init_state'] = processed_detect['state_map'].str[:2]
processed_detect['final_state'] = processed_detect['state_map'].str[3:5]

processed_detect.drop(columns = ['setup', 'exp_id'], inplace = True)



qwe = pd.read_csv(f'results/income_base/traceback/INCOMESIMPLE/compiled_similarity.csv')
qwe['state_map'] = qwe['target_init_final_state'] + '__' + qwe['initial_state_mapping']

qwe['init_state'] = qwe['target_init_final_state'].str[:2]
qwe['final_state'] = qwe['target_init_final_state'].str[-2:]


qwe[['A', 'B', 'C', 'D', 'E']] = qwe['initial_state_mapping'].str.split('_', expand = True)

def find_similar(row):
        match_cols = [col for col in ['A', 'B', 'C', 'D', 'E'] if row[col] == row['final_state']]
        return '_'.join(match_cols)

qwe['similar_districts'] = qwe.apply(find_similar, axis=1)
qwe['ground_truth'] = qwe['target_district_node'].str[0]
qwe = qwe[['state_map', 'A', 'B', 'C', 'D', 'E', 'similar_districts']].drop_duplicates()

processed_detect = pd.merge(processed_detect, qwe,
                           on = 'state_map', how = 'left')

processed_detect.head()
# Out:
#                state_map          period      drift_type  wrong_%  correct_%  \
# 0  LL_HL__HL_LL_LL_LL_ML     all_periods  first_vs_later    33.33      66.67
# 1  LL_HL__HL_LL_LL_LL_ML     all_periods         rolling     0.00     100.00
# 2  LL_HL__HL_LL_LL_LL_ML  first_4_months  first_vs_later     0.00     100.00
# 3  LL_HL__HL_LL_LL_LL_ML  first_4_months         rolling    33.33      66.67
# 4  LL_HL__HL_LL_LL_LL_ML      first_year  first_vs_later     0.00     100.00
#
#        method  skip_tgt       epochs_tgt  period_tgt  detection  ...  \
# 0  max cosine      True  selected_epochs  Overlapped          1  ...
# 1  max cosine      True  selected_epochs  Overlapped          1  ...
# 2  max cosine      True  selected_epochs  Overlapped          1  ...
# 3  max cosine      True  selected_epochs  Overlapped          1  ...
# 4  max cosine      True  selected_epochs  Overlapped          1  ...
#
#    interval  step_ratio  init_state  final_state   A   B   C   D   E  \
# 0         2       0.167          LL           HL  HL  LL  LL  LL  ML
# 1         2       0.167          LL           HL  HL  LL  LL  LL  ML
# 2         2       0.167          LL           HL  HL  LL  LL  LL  ML
# 3         2       0.167          LL           HL  HL  LL  LL  LL  ML
# 4         2       0.167          LL           HL  HL  LL  LL  LL  ML
#
#   similar_districts
# 0                 A
# 1                 A
# 2                 A
# 3                 A
# 4                 A
#
# [5 rows x 22 columns]

# %%
processed_detect['step_ratio'].value_counts()
# Out:
# step_ratio
# 0.167    8160
# 0.083    5440
# Name: count, dtype: int64

# %%
def plot_grid(data, x_var, y_var, hue_var, col_var, row_var,
             col_order = None, row_order = None, ylims = None, error_type='sd'):
    # Define FacetGrid with tighter spacing
    g = sns.FacetGrid(
        data = data,
        col=col_var,
        row=row_var,
        col_order=data[col_var].sort_values().unique() if col_order is None else col_order,
        row_order=data[row_var].sort_values().unique() if row_order is None else row_order,
        margin_titles=True,  # Helps use space better
        despine=False,  # Keeps axes for reference
        height=1.75,  # Smaller subplot height
        aspect=1  # Adjust aspect ratio (width / height)
    )
    
    # Map barplot with narrower bars
    g.map_dataframe(
        sns.barplot,
        x=x_var,
        y=y_var,
        order=data[x_var].sort_values().unique(),
        hue=hue_var,
        hue_order=data[hue_var].sort_values().unique(),
        width=.8,
        palette='Dark2',
        zorder=25,
        errorbar='sd' if error_type == 'sd' else 95,
        # capsize=1,
        err_kws={'color': 'black', 'linewidth' : 1}
    )
    
    # Reduce spacing between subplots
    g.fig.subplots_adjust(
        hspace=0.2,  # vertical space between rows
        wspace=0.05  # horizontal space between columns
    )
    
    # Reduce legend size and move to a compact position
    g.add_legend(title=hue_var)
    g._legend.set_bbox_to_anchor((1.25, 0.625))  # move legend to side
    g._legend.set_frame_on(False)

    ylims = (0, 100) if ylims is None else ylims
    # Optional: Rotate x-ticks and tighten layout
    for ax in g.axes.flat:
        for label in ax.get_xticklabels():
            label.set_rotation(45)
            label.set_fontsize(8)
        # ax.set_ylabel('')
        # ax.set_xlabel('')
        ax.set_ylim(ylims)
        y_min, y_max = ax.get_ylim()
        ax.set_yticks(np.arange(y_min, y_max + 1, 20))
        ax.grid(zorder = 0)
        for line in ax.lines:
            line.set_zorder(30)
            
    plt.tight_layout()
    plt.show()

# %%
processed_detect_P2 = processed_detect[(processed_detect['step_ratio'] != .444) & (processed_detect['step_ratio'] != .333) & (processed_detect['step_ratio'] != .667)]

processed_detect_P2 = processed_detect_P2[(processed_detect_P2['window'] != 6) & (processed_detect_P2['interval'] != 3) & (processed_detect_P2['window'] != 84)]

processed_detect_P2 = processed_detect[(processed_detect['period_tgt'] == 'Targeted') & 
                                                            (processed_detect['interval'] == 2) & 
                                                            (processed_detect['window'] == 12) & 
                                                            (processed_detect['epochs_tgt'] == 'all') & 
                                                            (processed_detect['skip_tgt'] == True)].copy()

processed_detect_P2['detection'] = processed_detect_P2['correct_%']

x_var = 'interval'
y_var = 'detection'
hue_var = 'step_size'

col_var = 'similar_districts'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = processed_detect_P2, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (0,100))

# %%
import glob
import os
import pandas as pd

# Step 1: Get all matching directories
base_path = 'results/income_base/traceback/HYPER_INCOME'
# base_path = 'results/density_base/traceback/HYPER'
pattern = os.path.join(base_path, '*2_*/')
directories = [d for d in glob.glob(pattern) if os.path.isdir(d)]

# Step 2: Count files in each directory

aux_det = []
aux_sim = []
aux_summ = []
for dir_path in directories:
    files = [f for f in glob.glob(os.path.join(dir_path, '*')) if os.path.isfile(f)]
    det = pd.read_csv(f'{dir_path}/compiled_detection.csv')
    sim = pd.read_csv(f'{dir_path}/compiled_similarity.csv')
    summ = pd.read_csv(f'{dir_path}/df_summary.csv')

    if len(summ['com_epoch'].unique()) != 1:
        raise ValueError('value should be unique!')

    summ['state_map'] = summ['exp_id']
    
    det = pd.merge(det, summ[['state_map', 'ground_truth','final_state', 'similar_districts', 'com_epoch']],
                  how = 'left', on = 'state_map')

    aux_det.append(det)
    aux_sim.append(sim)
    aux_summ.append(summ)

df_detect_hyper = pd.concat(aux_det, ignore_index=True)


processed_detect_hyper = df_detect_hyper.copy()
processed_detect_hyper[['window', 'step_size', 'interval', 'lstm', 'info']] = processed_detect_hyper['setup'].str.split('_', expand = True).astype(float)

for c in ['window', 'step_size', 'interval', 'lstm']:
    processed_detect_hyper[c] = processed_detect_hyper[c].astype(int)
    
processed_detect_hyper['interval'] = (processed_detect_hyper['interval'] / 3600).astype(int)
processed_detect_hyper['step_ratio'] = round(processed_detect_hyper['step_size']  / processed_detect_hyper['window'], 3)


processed_detect_hyper['init_state'] = processed_detect_hyper['state_map'].str[:2]
processed_detect_hyper['final_state'] = processed_detect_hyper['state_map'].str[3:5]

processed_detect_hyper.drop(columns = ['setup', 'exp_id', 'state_map'], inplace = True)

for c in ['window', 'step_size', 'interval', 'lstm', 'info', 'ground_truth','final_state', 'similar_districts', 'com_epoch']:
    print(c, processed_detect_hyper[c].unique().tolist())
    
plot_detect_hyper = processed_detect_hyper.copy()
plot_detect_hyper['detection'] = plot_detect_hyper['correct_%']


plot_detect_hyper = plot_detect_hyper[(plot_detect_hyper['period_tgt'] == 'Targeted') & 
                                                            (plot_detect_hyper['window'] == 12) & 
                                                            (plot_detect_hyper['epochs_tgt'] == 'all') & 
                                                            (plot_detect_hyper['com_epoch'] == 5) & 
                                                            (plot_detect_hyper['skip_tgt'] == True)]


x_var = 'lstm'
y_var = 'detection'
hue_var = 'info'

col_var = 'similar_districts'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = plot_detect_hyper, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (0,100))



# processed_detect_hyper_selected = processed_detect_hyper[(processed_detect_hyper['lstm'] == 30) & (processed_detect_hyper['info'] == 0.4)].copy()

# processed_detect_hyper_selected = processed_detect_hyper_selected[(processed_detect_hyper_selected['period_tgt'] == 'Targeted') & 
#                                                             (processed_detect_hyper_selected['epochs_tgt'] == 'all') & 
#                                                             (processed_detect_hyper_selected['skip_tgt'] == True)]

# processed_detect_hyper_selected['detection'] = processed_detect_hyper_selected['correct_%']


# x_var = 'drift_type'
# y_var = 'detection'
# hue_var = 'period'

# col_var = 'method'
# row_var = 'final_state'
# row_order = ['ML', 'HL']

# plot_grid(data = processed_detect_hyper_selected, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
#              col_order = None, row_order = row_order, ylims = (50,105))
# Out:
# window [12, 48, 84]
# step_size [2]
# interval [4]
# lstm [40, 10, 30, 60]
# info [0.4, 0.2, 0.05, 0.1]
# ground_truth ['B', 'C', 'D', 'E', 'A']
# final_state ['HL', 'ML']
# similar_districts ['A', 'B', 'C', 'D', 'E']
# com_epoch [10, 5]

# %%
import glob
import os
import pandas as pd

# Step 1: Get all matching directories
base_path = 'results/income_base/traceback/HYPER_INCOME'
# base_path = 'results/density_base/traceback/HYPER'
pattern = os.path.join(base_path, '*2_*/')
directories = [d for d in glob.glob(pattern) if os.path.isdir(d)]

# Step 2: Count files in each directory

aux_det = []
aux_sim = []
aux_summ = []
for dir_path in directories:
    files = [f for f in glob.glob(os.path.join(dir_path, '*')) if os.path.isfile(f)]
    det = pd.read_csv(f'{dir_path}/compiled_detection.csv')
    sim = pd.read_csv(f'{dir_path}/compiled_similarity.csv')
    summ = pd.read_csv(f'{dir_path}/df_summary.csv')

    if len(summ['com_epoch'].unique()) != 1:
        raise ValueError('value should be unique!')

    summ['state_map'] = summ['exp_id']
    
    det = pd.merge(det, summ[['state_map', 'ground_truth','final_state', 'similar_districts', 'com_epoch']],
                  how = 'left', on = 'state_map')

    aux_det.append(det)
    aux_sim.append(sim)
    aux_summ.append(summ)

df_detect_hyper = pd.concat(aux_det, ignore_index=True)


processed_detect_hyper = df_detect_hyper.copy()
processed_detect_hyper[['window', 'step_size', 'interval', 'lstm', 'info']] = processed_detect_hyper['setup'].str.split('_', expand = True).astype(float)

for c in ['window', 'step_size', 'interval', 'lstm']:
    processed_detect_hyper[c] = processed_detect_hyper[c].astype(int)
    
processed_detect_hyper['interval'] = (processed_detect_hyper['interval'] / 3600).astype(int)
processed_detect_hyper['step_ratio'] = round(processed_detect_hyper['step_size']  / processed_detect_hyper['window'], 3)


processed_detect_hyper['init_state'] = processed_detect_hyper['state_map'].str[:2]
processed_detect_hyper['final_state'] = processed_detect_hyper['state_map'].str[3:5]

processed_detect_hyper.drop(columns = ['setup', 'exp_id', 'state_map'], inplace = True)

for c in ['window', 'step_size', 'interval', 'lstm', 'info', 'ground_truth','final_state', 'similar_districts', 'com_epoch']:
    print(c, processed_detect_hyper[c].unique().tolist())
    
plot_detect_hyper = processed_detect_hyper.copy()
plot_detect_hyper['detection'] = plot_detect_hyper['correct_%']

x_var = 'lstm'
y_var = 'detection'
hue_var = 'info'

col_var = 'com_epoch'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = plot_detect_hyper, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (0,100))
# Out:
# window [12, 48, 84]
# step_size [2]
# interval [4]
# lstm [40, 10, 30, 60]
# info [0.4, 0.2, 0.05, 0.1]
# ground_truth ['B', 'C', 'D', 'E', 'A']
# final_state ['HL', 'ML']
# similar_districts ['A', 'B', 'C', 'D', 'E']
# com_epoch [10, 5]

# %%
plot_detect_hyper_A = processed_detect_hyper.copy()

# plot_detect_hyper_A = plot_detect_hyper_A[plot_detect_hyper_A['ground_truth'] == 'A']
plot_detect_hyper_A['detection'] = plot_detect_hyper_A['correct_%']

plot_detect_hyper_A = plot_detect_hyper_A[(plot_detect_hyper_A['period_tgt'] == 'Targeted') & 
                                                            (plot_detect_hyper_A['epochs_tgt'] == 'all') &
                                                            (plot_detect_hyper_A['window'] == 12) & 
                                                            (plot_detect_hyper_A['com_epoch'] == 5) &
                                                            (plot_detect_hyper_A['skip_tgt'] == True)]

x_var = 'lstm'
y_var = 'detection'
hue_var = 'info'

col_var = 'similar_districts'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = plot_detect_hyper_A, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (0,100))

# %%
2/12
# Out:
# 0.16666666666666666

# %%
processed_detect_hyper.head()
# Out:
#         period      drift_type  wrong_%  correct_%      method  skip_tgt  \
# 0  all_periods  first_vs_later    33.33      66.67  max cosine      True
# 1  all_periods  first_vs_later    33.33      66.67  max cosine      True
# 2  all_periods  first_vs_later    33.33      66.67  max cosine      True
# 3  all_periods  first_vs_later    33.33      66.67  max cosine      True
# 4  all_periods  first_vs_later    33.33      66.67  max cosine      True
#
#   epochs_tgt  period_tgt  detection ground_truth final_state  \
# 0       init  Overlapped          1            B          LH
# 1       init  Overlapped          1            B          LH
# 2       init  Overlapped          1            B          LH
# 3       init  Overlapped          1            B          LH
# 4       init  Overlapped          1            C          LH
#
#   similar_districts  com_epoch  window  step_size  interval  lstm  info  \
# 0                 A         10      12          2         4    10   0.1
# 1                 A         10      12          2         4    10   0.1
# 2                 A         10      12          2         4    10   0.1
# 3                 A         10      12          2         4    10   0.1
# 4                 A         10      12          2         4    10   0.1
#
#    step_ratio init_state
# 0       0.167         LL
# 1       0.167         LL
# 2       0.167         LL
# 3       0.167         LL
# 4       0.167         LL

# %%
qwe = plot_detect_P2_selected.copy()
qwe[(qwe['period'] == 'all_periods') & (qwe['method'] == 'max cosine')]
# Out:
#    final_state epochs_tgt  skip_tgt       period period_tgt      drift_type  \
# 0           LH        all      True  all_periods   Targeted  first_vs_later
# 3           LH        all      True  all_periods   Targeted         rolling
# 14          LM        all      True  all_periods   Targeted  first_vs_later
# 17          LM        all      True  all_periods   Targeted         rolling
#
#         method  correct_%  count   detection
# 0   max cosine      900.0      9  100.000000
# 3   max cosine      900.0      9  100.000000
# 14  max cosine      700.0      9   77.777778
# 17  max cosine      800.0      9   88.888889

# %%
for c in ['epochs_tgt', 'skip_tgt',
          'period', 'period_tgt',
          'drift_type', 'method']:
    print(c, plot_detect_P2_selected[c].unique())
# Out:
# epochs_tgt ['all']
# skip_tgt [ True]
# period ['all_periods' 'all_year' 'first_4_months']
# period_tgt ['Targeted']
# drift_type ['first_vs_later' 'rolling']
# method ['max cosine' 'rank cosine_mean' 'rank cosine_sum' 'summary']

# %%
df_detect_income = pd.read_csv(f'results/income_base/traceback/INCOMESIMPLE/compiled_detection.csv')

processed_detect_income = df_detect_income.copy()
processed_detect_income[['window', 'step_size', 'interval']] = processed_detect_income['setup'].str.split('_', expand = True).astype(int)

processed_detect_income['interval'] = (processed_detect_income['interval'] / 3600).astype(int)
processed_detect_income['step_ratio'] = round(processed_detect_income['step_size']  / processed_detect_income['window'], 3)


processed_detect_income['init_state'] = processed_detect_income['state_map'].str[:2]
processed_detect_income['final_state'] = processed_detect_income['state_map'].str[3:5]

processed_detect_income.drop(columns = ['setup', 'exp_id', 'state_map'], inplace = True)

processed_detect_income.head()
# Out:
#            period      drift_type  wrong_%  correct_%      method  skip_tgt  \
# 0     all_periods  first_vs_later    33.33      66.67  max cosine      True
# 1     all_periods         rolling     0.00     100.00  max cosine      True
# 2  first_4_months  first_vs_later     0.00     100.00  max cosine      True
# 3  first_4_months         rolling    33.33      66.67  max cosine      True
# 4      first_year  first_vs_later     0.00     100.00  max cosine      True
#
#         epochs_tgt  period_tgt  detection  window  step_size  interval  \
# 0  selected_epochs  Overlapped          1      12          2         2
# 1  selected_epochs  Overlapped          1      12          2         2
# 2  selected_epochs  Overlapped          1      12          2         2
# 3  selected_epochs  Overlapped          1      12          2         2
# 4  selected_epochs  Overlapped          1      12          2         2
#
#    step_ratio init_state final_state
# 0       0.167         LL          HL
# 1       0.167         LL          HL
# 2       0.167         LL          HL
# 3       0.167         LL          HL
# 4       0.167         LL          HL

# %%
processed_detect_income_P2 = processed_detect_income.copy()

processed_detect_income_P2['detection'] = processed_detect_income_P2['correct_%']

x_var = 'interval'
y_var = 'detection'
hue_var = 'step_ratio'

col_var = 'window'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = processed_detect_income_P2, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (50,100))

# %%
# plot_detect_income = processed_detect_income.groupby(['final_state', 'epochs_tgt', 'skip_tgt',  # epocas utilizadas
#                                                                  'period', 'period_tgt',    # meses (labels) considerados
#                                                                  'drift_type', 'method']  # tipo análise
#                                                               ).agg({
#                                                                 'correct_%' : 'sum',
#                                                                 'period' : 'count'
#                                                             }).rename(columns = {'period' : 'count'}).reset_index()

# plot_detect_income['detection'] = plot_detect_income['correct_%'] / plot_detect_income['count']

plot_detect_income = processed_detect_income.copy()
plot_detect_income['detection'] = plot_detect_income['correct_%']

plot_detect_income = plot_detect_income[(plot_detect_income['period_tgt'] == 'Targeted') & 
                                        (plot_detect_income['epochs_tgt'] == 'all') & 
                                        (plot_detect_income['skip_tgt'] == True)]

x_var = 'drift_type'
y_var = 'detection'
hue_var = 'period'

col_var = 'method'
row_var = 'final_state'
row_order = ['ML', 'HL']

plot_grid(data = plot_detect_income, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (30,105))

# %%
import glob
import os
import pandas as pd

# Step 1: Get all matching directories
base_path = 'results/income_base/traceback/HYPER_INCOME'
# base_path = 'results/density_base/traceback/HYPER'
pattern = os.path.join(base_path, '*2_*/')
directories = [d for d in glob.glob(pattern) if os.path.isdir(d)]

# Step 2: Count files in each directory

aux_det = []
aux_sim = []

for dir_path in directories:
    files = [f for f in glob.glob(os.path.join(dir_path, '*')) if os.path.isfile(f)]
    det = pd.read_csv(f'{dir_path}/compiled_detection.csv')
    sim = pd.read_csv(f'{dir_path}/compiled_similarity.csv')

    aux_det.append(det)
    aux_sim.append(sim)

df_detect_hyper = pd.concat(aux_det, ignore_index=True)
df_detect_hyper.head()
# Out:
#                state_map          period      drift_type  wrong_%  correct_%  \
# 0  LL_HL__HL_LL_LL_LL_ML     all_periods  first_vs_later    33.33      66.67
# 1  LL_HL__HL_LL_LL_LL_ML     all_periods         rolling    40.00      60.00
# 2  LL_HL__HL_LL_LL_LL_ML  first_4_months  first_vs_later     0.00     100.00
# 3  LL_HL__HL_LL_LL_LL_ML  first_4_months         rolling    33.33      66.67
# 4  LL_HL__HL_LL_LL_LL_ML      first_year  first_vs_later     0.00     100.00
#
#                setup      method  skip_tgt epochs_tgt  period_tgt  detection  \
# 0  12_2_14400_40_0.4  max cosine      True       init  Overlapped          1
# 1  12_2_14400_40_0.4  max cosine      True       init  Overlapped          1
# 2  12_2_14400_40_0.4  max cosine      True       init  Overlapped          1
# 3  12_2_14400_40_0.4  max cosine      True       init  Overlapped          1
# 4  12_2_14400_40_0.4  max cosine      True       init  Overlapped          1
#
#          exp_id
# 0  HYPER_INCOME
# 1  HYPER_INCOME
# 2  HYPER_INCOME
# 3  HYPER_INCOME
# 4  HYPER_INCOME

# %%
processed_detect_hyper = df_detect_hyper.copy()
processed_detect_hyper[['window', 'step_size', 'interval', 'lstm', 'info']] = processed_detect_hyper['setup'].str.split('_', expand = True).astype(float)

for c in ['window', 'step_size', 'interval', 'lstm']:
    processed_detect_hyper[c] = processed_detect_hyper[c].astype(int)
    
processed_detect_hyper['interval'] = (processed_detect_hyper['interval'] / 3600).astype(int)
processed_detect_hyper['step_ratio'] = round(processed_detect_hyper['step_size']  / processed_detect_hyper['window'], 3)


processed_detect_hyper['init_state'] = processed_detect_hyper['state_map'].str[:2]
processed_detect_hyper['final_state'] = processed_detect_hyper['state_map'].str[3:5]

processed_detect_hyper.drop(columns = ['setup', 'exp_id', 'state_map'], inplace = True)

for c in ['window', 'step_size', 'interval', 'lstm', 'info']:
    print(c, processed_detect_hyper[c].unique().tolist())
    
processed_detect_hyper.head()
# Out:
# window [12, 48, 84]
# step_size [2]
# interval [4]
# lstm [40, 10, 30, 60]
# info [0.4, 0.2, 0.05, 0.1]
#            period      drift_type  wrong_%  correct_%      method  skip_tgt  \
# 0     all_periods  first_vs_later    33.33      66.67  max cosine      True
# 1     all_periods         rolling    40.00      60.00  max cosine      True
# 2  first_4_months  first_vs_later     0.00     100.00  max cosine      True
# 3  first_4_months         rolling    33.33      66.67  max cosine      True
# 4      first_year  first_vs_later     0.00     100.00  max cosine      True
#
#   epochs_tgt  period_tgt  detection  window  step_size  interval  lstm  info  \
# 0       init  Overlapped          1      12          2         4    40   0.4
# 1       init  Overlapped          1      12          2         4    40   0.4
# 2       init  Overlapped          1      12          2         4    40   0.4
# 3       init  Overlapped          1      12          2         4    40   0.4
# 4       init  Overlapped          1      12          2         4    40   0.4
#
#    step_ratio init_state final_state
# 0       0.167         LL          HL
# 1       0.167         LL          HL
# 2       0.167         LL          HL
# 3       0.167         LL          HL
# 4       0.167         LL          HL

# %%
plot_detect_hyper = processed_detect_hyper.groupby(['final_state', 'window', 'lstm', 'info'] 
                                                              ).agg({
                                                                'correct_%' : 'sum',
                                                                'period' : 'count'
                                                            }).rename(columns = {'period' : 'count'}).reset_index()

plot_detect_hyper['detection'] = plot_detect_hyper['correct_%'] / plot_detect_hyper['count']

x_var = 'lstm'
y_var = 'detection'
hue_var = 'info'

col_var = 'window'
row_var = 'final_state'

row_order = ['ML', 'HL']

plot_grid(data = plot_detect_hyper, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (30,105))

# %%
processed_detect_hyper_selected = processed_detect_hyper[(processed_detect_hyper['lstm'] == 30) & (processed_detect_hyper['info'] == 0.1)]

processed_detect_hyper_selected = processed_detect_hyper_selected[(processed_detect_hyper_selected['period_tgt'] == 'Targeted') & 
                                                            (processed_detect_hyper_selected['epochs_tgt'] == 'all') & 
                                                            (processed_detect_hyper_selected['skip_tgt'] == True)]


plot_detect_hyper_selected = processed_detect_hyper_selected.groupby(['final_state', 'epochs_tgt', 'skip_tgt',  # epocas utilizadas
                                                                 'period', 'period_tgt',    # meses (labels) considerados
                                                                 'drift_type', 'method']  # tipo análise
                                                              ).agg({
                                                                'correct_%' : 'sum',
                                                                'period' : 'count'
                                                            }).rename(columns = {'period' : 'count'}).reset_index()

plot_detect_hyper_selected['detection'] = plot_detect_hyper_selected['correct_%'] / plot_detect_hyper_selected['count']


x_var = 'drift_type'
y_var = 'detection'
hue_var = 'period'

col_var = 'method'
row_var = 'final_state'
row_order = ['ML', 'HL']

plot_grid(data = plot_detect_hyper_selected, x_var = x_var, y_var = y_var, hue_var = hue_var, col_var = col_var, row_var = row_var,
             col_order = None, row_order = row_order, ylims = (50,105))

# %%
plot_detect_hyper_selected[plot_detect_hyper_selected['final_state'] == 'ML'].sort_values(by = 'detection', ascending = False).head(5)
# Out:
#    final_state epochs_tgt  skip_tgt          period period_tgt  \
# 20          ML        all      True        all_year   Targeted
# 25          ML        all      True  first_4_months   Targeted
# 22          ML        all      True  first_4_months   Targeted
# 21          ML        all      True        all_year   Targeted
# 26          ML        all      True  first_4_months   Targeted
#
#         drift_type            method  correct_%  count  detection
# 20  first_vs_later           summary    1300.01     17  76.471176
# 25         rolling        max cosine    1216.66     17  71.568235
# 22  first_vs_later        max cosine    1200.01     17  70.588824
# 21         rolling           summary    1133.33     17  66.666471
# 26         rolling  rank cosine_mean    1100.00     17  64.705882

# %%
plot_detect_income[plot_detect_income['final_state'] == 'ML'].sort_values(by = 'detection', ascending = False).head(5)
# Out:
#     final_state epochs_tgt  skip_tgt          period period_tgt  \
# 214          ML        all      True        all_year   Targeted
# 210          ML        all      True     all_periods   Targeted
# 211          ML        all      True     all_periods   Targeted
# 225          ML        all      True  first_4_months   Targeted
# 222          ML        all      True  first_4_months   Targeted
#
#          drift_type            method  correct_%  count  detection
# 214  first_vs_later           summary    3800.05     51  74.510784
# 210         rolling  rank cosine_mean    3683.37     51  72.222941
# 211         rolling   rank cosine_sum    3683.37     51  72.222941
# 225         rolling        max cosine    3650.01     51  71.568824
# 222  first_vs_later        max cosine    3633.33     51  71.241765
